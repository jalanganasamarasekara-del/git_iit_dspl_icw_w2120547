# %% [markdown]
# <a href="https://colab.research.google.com/github/jalanganasamarasekara-del/git_iit_dspl_icw_w2120547/blob/main/W2120547_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import random
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/DSPL_ICW_W2120547/Data/Raw/global_currency_2026.csv')

# %%
df.head()
# Out:
#   ISO3      country   adm1_name adm2_name    mkt_name    lat    lon  \
# 0  AFG  Afghanistan  Badakhshan      Argo  Badakhshan  37.04  70.46
# 1  AFG  Afghanistan  Badakhshan      Argo  Badakhshan  37.04  70.46
# 2  AFG  Afghanistan  Badakhshan      Argo  Badakhshan  37.04  70.46
# 3  AFG  Afghanistan  Badakhshan      Argo  Badakhshan  37.04  70.46
# 4  AFG  Afghanistan     Badghis    Jawand     Badghis  35.14  63.73
#
#                    geo_id       DATES  year  ...  \
# 0  gid_370400000704600000  2026-01-01  2026  ...
# 1  gid_370400000704600000  2026-02-01  2026  ...
# 2  gid_370400000704600000  2026-03-01  2026  ...
# 3  gid_370400000704600000  2026-04-01  2026  ...
# 4  gid_351400000637300000  2026-01-01  2026  ...
#
#    l_wage_non_qualified_labour_non_agricultural  \
# 0                                        300.00
# 1                                        281.55
# 2                                        303.67
# 3                                        308.42
# ...

# %%
df.shape
# Out:
# (12447, 82)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12447 entries, 0 to 12446
# Data columns (total 82 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   ISO3                                                  12447 non-null  object
#  1   country                                               12447 non-null  object
#  2   adm1_name                                             12447 non-null  object
#  3   adm2_name                                             12447 non-null  object
#  4   mkt_name                                              12447 non-null  object
#  5   lat                                                   12296 non-null  float64
#  6   lon                                                   12296 non-null  float64
#  7   geo_id                                                12447 non-null  object
# ...

# %%
df.describe()
# Out:
#                 lat           lon     year         month  batteries  candles  \
# count  12296.000000  12296.000000  12447.0  12447.000000        0.0      0.0
# mean       3.086654     41.343419   2026.0      2.496987        NaN      NaN
# std       15.933434     36.504701      0.0      1.117176        NaN      NaN
# min      -26.340000    -90.560000   2026.0      1.000000        NaN      NaN
# 25%       -7.040000     17.060000   2026.0      1.000000        NaN      NaN
# 50%        4.580000     36.805000   2026.0      2.000000        NaN      NaN
# 75%       13.962500     47.840000   2026.0      3.000000        NaN      NaN
# max       40.900000    140.700000   2026.0      4.000000        NaN      NaN
#
#        charcoal  exchange_rate_unofficial  milling_cost_sorghum  \
# count       0.0              12194.000000             23.000000
# mean        NaN               4204.432742           3900.369565
# std         NaN              10017.541240           2349.062135
# ...

# %%
df = df[['DATES', 'country', 'mkt_name', 'currency', 'exchange_rate_unofficial']]

# %%
df.head()
# Out:
#         DATES      country    mkt_name currency  exchange_rate_unofficial
# 0  2026-01-01  Afghanistan  Badakhshan      AFN                     66.00
# 1  2026-02-01  Afghanistan  Badakhshan      AFN                       NaN
# 2  2026-03-01  Afghanistan  Badakhshan      AFN                     64.27
# 3  2026-04-01  Afghanistan  Badakhshan      AFN                       NaN
# 4  2026-01-01  Afghanistan     Badghis      AFN                     66.00

# %%
df.rename(columns={'exchange_rate_unofficial':'Exchange_Rate'}, inplace=True)

# %%
df.rename(columns={'country':'Country'}, inplace=True)

# %%
df.rename(columns={'DATES':'Dates'}, inplace=True)

# %%
df.rename(columns={'mkt_name':'Market Name'}, inplace=True)

# %%
df.rename(columns={'currency':'Currency'}, inplace=True)

# %%
df.head()
# Out:
#         Dates      Country Market Name Currency  Exchange_Rate
# 0  2026-01-01  Afghanistan  Badakhshan      AFN          66.00
# 1  2026-02-01  Afghanistan  Badakhshan      AFN            NaN
# 2  2026-03-01  Afghanistan  Badakhshan      AFN          64.27
# 3  2026-04-01  Afghanistan  Badakhshan      AFN            NaN
# 4  2026-01-01  Afghanistan     Badghis      AFN          66.00

# %%
df.isnull().sum()
# Out:
# Dates              0
# Country            0
# Market Name        0
# Currency           0
# Exchange_Rate    253
# dtype: int64

# %%
df.dropna()
# Out:
#             Dates      Country                                 Market Name  \
# 0      2026-01-01  Afghanistan                                  Badakhshan
# 2      2026-03-01  Afghanistan                                  Badakhshan
# 4      2026-01-01  Afghanistan                                     Badghis
# 5      2026-02-01  Afghanistan                                     Badghis
# 6      2026-03-01  Afghanistan                                     Badghis
# ...           ...          ...                                         ...
# 12382  2026-02-01  Yemen, Rep.                                  Al Ghaidha
# 12403  2026-02-01  Yemen, Rep.  Central Ataq - Al Nasib neighbour - Darhim
# 12421  2026-02-01  Yemen, Rep.                      Marib City - Al mujmaa
# 12436  2026-02-01  Yemen, Rep.                           Soqatra (Hudaibo)
# 12439  2026-02-01  Yemen, Rep.                                   Taiz City
#
#       Currency  Exchange_Rate
# 0          AFN          66.00
# ...

# %%
df.isnull().sum()
# Out:
# Dates              0
# Country            0
# Market Name        0
# Currency           0
# Exchange_Rate    253
# dtype: int64

# %%
df = df.dropna(subset=['Exchange_Rate'])

# %%
df.head()
# Out:
#         Dates      Country Market Name Currency  Exchange_Rate
# 0  2026-01-01  Afghanistan  Badakhshan      AFN          66.00
# 2  2026-03-01  Afghanistan  Badakhshan      AFN          64.27
# 4  2026-01-01  Afghanistan     Badghis      AFN          66.00
# 5  2026-02-01  Afghanistan     Badghis      AFN          64.07
# 6  2026-03-01  Afghanistan     Badghis      AFN          64.95

# %%
df.dtypes
# Out:
# Dates             object
# Country           object
# Market Name       object
# Currency          object
# Exchange_Rate    float64
# dtype: object

# %%
df['Dates'] = pd.to_datetime(df['Dates'])
